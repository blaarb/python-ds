# %%
import numpy as np
import pandas as pd
import seaborn as sns
penguins = sns.load_dataset('penguins')
penguins.info()
print(penguins["species"].value_counts())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB
# Adelie       152
# Gentoo       124
# Chinstrap     68
# Name: species, dtype: int64

# %%
gentoo_flippers = penguins.loc[penguins["species"] == 'Gentoo', "flipper_length_mm"]
adelie_flippers_sample = list(penguins.loc[penguins["species"] == 'Adelie', "flipper_length_mm"].sample(49))
gentoo_flippers_sample01 = list(gentoo_flippers[:49])
gentoo_flippers_sample02 = list(gentoo_flippers[50:99])

# %%
sns.histplot(gentoo_flippers)
# Out:
# <AxesSubplot:xlabel='flipper_length_mm', ylabel='Count'>

# %%
# compare_df = pd.DataFrame({"gentoo_flippers_sample01": gentoo_flippers_sample01, "gentoo_flippers_sample02": gentoo_flippers_sample02})
# compare_df
# Out:
#     gentoo_flippers_sample01  gentoo_flippers_sample02
# 0                      211.0                     210.0
# 1                      230.0                     220.0
# 2                      210.0                     210.0
# 3                      218.0                     225.0
# 4                      215.0                     217.0
# 5                      210.0                     220.0
# 6                      211.0                     208.0
# 7                      219.0                     220.0
# 8                      209.0                     208.0
# 9                      215.0                     224.0
# 10                     214.0                     208.0
# 11                     216.0                     221.0
# 12                     214.0                     214.0
# 13                     213.0                     231.0
# 14                     210.0                     219.0
# 15                     217.0                     230.0
# ...

# %%
from scipy.stats import ttest_ind
t_stat, p_val = ttest_ind(gentoo_flippers_sample01, gentoo_flippers_sample02)
print(f"t_stat: {t_stat}, p_val: {p_val}")
print(f"mean для выборки 1: {np.mean(gentoo_flippers_sample01)}\nmean для выборки 2: {np.mean(gentoo_flippers_sample02)}")
# Out:
# t_stat: -2.6036553608549458, p_val: 0.01068756602801877
# mean для выборки 1: 215.26530612244898
# mean для выборки 2: 218.55102040816325

# %% [markdown]
# Сравнение с пингвинами другого вида

# %%
t_stat, p_val = ttest_ind(gentoo_flippers_sample01, adelie_flippers_sample)
print(f"t_stat: {t_stat}, p_val: {p_val}")
print(f"mean для выборки 1: {np.mean(gentoo_flippers_sample01)}\nmean для выборки 2: {np.mean(adelie_flippers_sample)}")
# Out:
# t_stat: 21.62016779972882, p_val: 1.1427967748027536e-38
# mean для выборки 1: 215.26530612244898
# mean для выборки 2: 190.08163265306123
